# %% [markdown]
# # Code for Rapid Retraining
#
# Adapted from original code of the [rapid retraning paper](https://ieeexplore.ieee.org/document/9796721).
#
# Create a virtual environment using conda by
#
# ```shell
# conda create -n liu+22 python=3.6.13
# ```
#
# and activating it
#
# ```shell
# conda activate liu+22
# ```
#
# Then, install required packages
#
# ```
# # This file may be used to create an environment using:
# # $ conda create --name <env> --file <this file>
# # platform: linux-64
# _libgcc_mutex=0.1=main
# _openmp_mutex=5.1=1_gnu
# blas=1.0=mkl
# ca-certificates=2022.10.11=h06a4308_0
# certifi=2021.5.30=py36h06a4308_0
# cffi=1.14.6=py36h400218f_0
# cycler=0.11.0=pyhd3eb1b0_0
# dbus=1.13.18=hb2f20db_0
# expat=2.4.9=h6a678d5_0
# fontconfig=2.13.1=hef1e5e3_1
# freetype=2.12.1=h4a9f257_0
# glib=2.69.1=h4ff587b_1
# gst-plugins-base=1.14.0=h8213a91_2
# gstreamer=1.14.0=h28cd5cc_2
# icu=58.2=he6710b0_3
# intel-openmp=2022.1.0=h9e868ea_3769
# joblib=1.0.1=pyhd3eb1b0_0
# jpeg=9e=h7f8727e_0
# kiwisolver=1.3.1=py36h2531618_0
# lcms2=2.12=h3be6417_0
# ld_impl_linux-64=2.38=h1181459_1
# lerc=3.0=h295c915_0
# libdeflate=1.8=h7f8727e_5
# libffi=3.3=he6710b0_2
# libgcc-ng=11.2.0=h1234567_1
# libgfortran-ng=7.5.0=ha8ba4b0_17
# libgfortran4=7.5.0=ha8ba4b0_17
# libgomp=11.2.0=h1234567_1
# libpng=1.6.37=hbc83047_0
# libstdcxx-ng=11.2.0=h1234567_1
# libtiff=4.4.0=hecacb30_2
# libuuid=1.41.5=h5eee18b_0
# libwebp-base=1.2.4=h5eee18b_0
# libxcb=1.15=h7f8727e_0
# libxml2=2.9.14=h74e7548_0
# lz4-c=1.9.3=h295c915_1
# matplotlib=3.3.4=py36h06a4308_0
# matplotlib-base=3.3.4=py36h62a2d02_0
# mkl=2020.2=256
# mkl-service=2.3.0=py36he8ac12f_0
# mkl_fft=1.3.0=py36h54f3939_0
# mkl_random=1.1.1=py36h0573a6f_0
# ncurses=6.3=h5eee18b_3
# ninja=1.10.2=h06a4308_5
# ninja-base=1.10.2=hd09550d_5
# numpy=1.19.2=py36h54aff64_0
# numpy-base=1.19.2=py36hfa32c7d_0
# olefile=0.46=py36_0
# openjpeg=2.4.0=h3ad879b_0
# openssl=1.1.1s=h7f8727e_0
# pandas=1.1.5=py36ha9443f7_0
# pcre=8.45=h295c915_0
# pillow=8.3.1=py36h2c7a002_0
# pip=21.2.2=py36h06a4308_0
# pycparser=2.21=pyhd3eb1b0_0
# pyparsing=3.0.4=pyhd3eb1b0_0
# pyqt=5.9.2=py36h05f1152_2
# python=3.6.13=h12debd9_1
# python-dateutil=2.8.2=pyhd3eb1b0_0
# pytorch=0.4.1=py36_py35_py27__9.0.176_7.1.2_2
# pytz=2021.3=pyhd3eb1b0_0
# qt=5.9.7=h5867ecd_1
# readline=8.2=h5eee18b_0
# scikit-learn=0.24.2=py36ha9443f7_0
# scipy=1.5.2=py36h0b6359f_0
# setuptools=58.0.4=py36h06a4308_0
# sip=4.19.8=py36hf484d3e_0
# six=1.16.0=pyhd3eb1b0_1
# sqlite=3.39.3=h5082296_0
# threadpoolctl=2.2.0=pyh0d69192_0
# tk=8.6.12=h1ccaba5_0
# torchvision=0.2.1=py_2
# tornado=6.1=py36h27cfd23_0
# wheel=0.37.1=pyhd3eb1b0_0
# xz=5.2.6=h5eee18b_0
# zlib=1.2.13=h5eee18b_0
# zstd=1.5.2=ha4553b6_0
# ```
#
# Clone the code provided by the paper
#
# ```shell
# git clone https://github.com/MoonkeyBoy/The-Right-to-be-Forgotten-in-Federated-Learning-An-Efficient-Realization-with-Rapid-Retraining.git
# ```
#
# Run the code
#
# ```shell
# # Example, using GPU #0 and MNIST dataset, see code for more dataset options
# python main_unlearning.py --gpu 0 --dataset mnist
# ```
#
# Substitute `main_unlearning.py` with `main_unlearning_baseline.py` to check baseline.
#
# # References
#
# - Y. Liu, L. Xu, X. Yuan, C. Wang, and B. Li, “The Right to be Forgotten in Federated Learning: An Efficient Realization with Rapid Retraining,” May 2022. doi: 10.1109/infocom48880.2022.9796721. [[Paper](https://ieeexplore.ieee.org/document/9796721)]
